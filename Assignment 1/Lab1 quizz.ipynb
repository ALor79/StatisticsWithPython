# %%
#importing lybraries
import numpy as np
import scipy as sp
import pandas as pd

# %%
weather=data = pd.read_csv('weather2019.csv')
print(data.describe()) 
print(weather[weather.date=='21-Aug-19'].maxtemp)
# Out:
#           maxtemp     mintemp        rain        wind         sun
# count  364.000000  364.000000  364.000000  364.000000  364.000000
# mean    13.493681    5.818132    2.407967    9.101099    3.881044
# std      4.782387    4.418419    4.522745    3.354845    3.584432
# min      3.400000   -5.800000    0.000000    3.200000    0.000000
# 25%      9.800000    2.375000    0.000000    6.500000    0.500000
# 50%     13.100000    5.650000    0.300000    8.500000    3.250000
# 75%     17.325000    8.900000    2.450000   11.225000    6.300000
# max     24.900000   17.800000   24.200000   24.000000   15.500000
# 232    16.2
# Name: maxtemp, dtype: float64

# %%
from pandas import DataFrame

# %%
df = DataFrame(weather)

# %%
#finding the mean of maxtemp
print(df.maxtemp.mean())
# Out:
# 13.493681318681304

# %%
#finding the lowest of maxtemp
print(df.mintemp.max())
# Out:
# 17.8

# %%
#finding the median of maxtemp
print(df.maxtemp.median())
# Out:
# 13.1

# %%
#finding the standard deviation of mintemp
print(df.mintemp.std())
# Out:
# 4.41841885187529

# %%
#finding the day with minimum wind
min_wind_date=weather.loc[data['wind'].idxmin(),'date']

# %%
print(min_wind_date)
# Out:
# 11-Apr-19

# %%
#checking the corolation between mintemp and maxtemp
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(weather.mintemp,weather.maxtemp)
plt.xlabel('mintemp')
plt.ylabel('maxtemp')
# Out:
# Text(0, 0.5, 'maxtemp')

# %%
#
plt.figure()
plt.hist(data.rain,bins=20,alpha=1,label='rain')
plt.xlabel('rainfall')
plt.ylabel('number of days')
# Out:
# Text(0, 0.5, 'number of days')

# %%
#checking which letter colors the plt.plot black
plt.plot([1,2,2,3,4],'k')

# %%
#checking which string makes plt.plot alternate between dash and dot
plt.plot([1,2,2,3,4],'-.')
